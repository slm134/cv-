# %% [markdown]
# # Task2 数据读取与数据扩增

# %% [markdown]
# ## 2 数据读取与数据扩增

# %% [markdown]
# ### 2.1 图像读取

# %% [markdown]
# #### 2.2.1 pillow

# %%
from PIL import Image
from matplotlib import pyplot as plt
# 导入Pillow库

# 读取图片
im = Image.open('/home/susu/图片/1930544162.jpg')
plt.imshow(im)

# %% [markdown]
# #### 图像模糊

# %%
from PIL import Image, ImageFilter
im = Image.open('/home/susu/图片/1930544162.jpg')
im2 = im.filter(ImageFilter.BLUR)
im2.save('blur.jpg', 'jpeg')
plt.imshow(im2)

# %% [markdown]
# #### 图像裁减大小

# %%
from PIL import Image
im = Image.open('/home/susu/图片/1930544162.jpg')
w, h = im.size
print(w,h)
# Out:
# 1278 1496

# %%
im.thumbnail((w//2, h//2))
im.save('thumbnail.jpg', 'jpeg')
w2, h2 = im.size
print(w2, h2)
# Out:
# 639 748

# %% [markdown]
# Pillow官方文档：https://pillow.readthedocs.io/en/stable/

# %% [markdown]
# #### 2.2.2 OpenCV

# %%
import cv2
# 导入Opencv库
img = cv2.imread('/home/susu/图片/1930544162.jpg')
#Opencv默认颜色通道顺序是BRG，转换一下
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import cv2
# 导入Opencv库
img = cv2.imread('/home/susu/图片/1930544162.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# 转换为灰度图
plt.imshow(img)

# %%
import cv2
# 导入Opencv库
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# 转换为灰度图
